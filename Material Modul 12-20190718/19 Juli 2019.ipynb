# %%
import pandas as pd

# %%
df = pd.read_csv('flights.csv')
df.head(100) # kenapa jam satuannya float instead of int?
# Out:
#     Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0            1  2013      1    1     517.0             515        2.0
# 1            2  2013      1    1     533.0             529        4.0
# 2            3  2013      1    1     542.0             540        2.0
# 3            4  2013      1    1     544.0             545       -1.0
# 4            5  2013      1    1     554.0             600       -6.0
# 5            6  2013      1    1     554.0             558       -4.0
# 6            7  2013      1    1     555.0             600       -5.0
# 7            8  2013      1    1     557.0             600       -3.0
# 8            9  2013      1    1     557.0             600       -3.0
# 9           10  2013      1    1     558.0             600       -2.0
# 10          11  2013      1    1     558.0             600       -2.0
# 11          12  2013      1    1     558.0             600       -2.0
# ...

# %%
df.columns

# tailnum itu nomor ekor di ekor pesawat
# origin adalah bandara asal
# air time menunjukkan berapa lama pesawat mengudara, setelah take off
# distance dalam mile
# Out:
# Index(['Unnamed: 0', 'year', 'month', 'day', 'dep_time', 'sched_dep_time',
#        'dep_delay', 'arr_time', 'sched_arr_time', 'arr_delay', 'carrier',
#        'flight', 'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour',
#        'minute', 'time_hour'],
#       dtype='object')

# %%
df['origin'].unique()
# Out:
# array(['EWR', 'LGA', 'JFK'], dtype=object)

# %%
df['dest'].unique()
# Out:
# array(['IAH', 'MIA', 'BQN', 'ATL', 'ORD', 'FLL', 'IAD', 'MCO', 'PBI',
#        'TPA', 'LAX', 'SFO', 'DFW', 'BOS', 'LAS', 'MSP', 'DTW', 'RSW',
#        'SJU', 'PHX', 'BWI', 'CLT', 'BUF', 'DEN', 'SNA', 'MSY', 'SLC',
#        'XNA', 'MKE', 'SEA', 'ROC', 'SYR', 'SRQ', 'RDU', 'CMH', 'JAX',
#        'CHS', 'MEM', 'PIT', 'SAN', 'DCA', 'CLE', 'STL', 'MYR', 'JAC',
#        'MDW', 'HNL', 'BNA', 'AUS', 'BTV', 'PHL', 'STT', 'EGE', 'AVL',
#        'PWM', 'IND', 'SAV', 'CAK', 'HOU', 'LGB', 'DAY', 'ALB', 'BDL',
#        'MHT', 'MSN', 'GSO', 'CVG', 'BUR', 'RIC', 'GSP', 'GRR', 'MCI',
#        'ORF', 'SAT', 'SDF', 'PDX', 'SJC', 'OMA', 'CRW', 'OAK', 'SMF',
#        'TUL', 'TYS', 'OKC', 'PVD', 'DSM', 'PSE', 'BHM', 'CAE', 'HDN',
#        'BZN', 'MTJ', 'EYW', 'PSP', 'ACK', 'BGR', 'ABQ', 'ILM', 'MVY',
#        'SBN', 'LEX', 'CHO', 'TVC', 'ANC', 'LGA'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2013], dtype=int64)

# %%
# Berapa banyak penerbangan di bulan Januari?
